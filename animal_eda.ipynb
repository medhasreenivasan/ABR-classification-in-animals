# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.1 Introduction
# 1. Why choose this dataset ?
# 2. What is the motivation to solve this problem?
# 3. Why should it be of interest others ?

# %% [markdown]
# ## 1.2 Data Description

# %%
animal_data = pd.read_csv("animal_data.csv")
animal_data[animal_data['Group']=='91db']
# Out:
#    Group Levels SubjectID  Run  A_C1W1T0  A_C2W1T0  L_C1W1T0   L_C2W1T0  \
# 21  91db  70_70   21003-1    1  0.000005  0.000006  1.229508  11.147541
# 22  91db  70_90   21003-1    1  0.000006  0.000006  1.270492  11.147541
# 23  91db  90_90   21003-1    1  0.000005  0.000005  1.188525  11.106557
# 24  91db  70_70   21003-2    1  0.000005  0.000006  1.270492  11.188525
# 25  91db  70_90   21003-2    1  0.000004  0.000008  1.270492  11.147541
# 26  91db  90_90   21003-2    1  0.000008  0.000007  1.270492  11.188525
# 27  91db  70_70   21004-1    1  0.000004  0.000006  1.311475  11.229508
# 28  91db  70_90   21004-1    1  0.000005  0.000008  1.311475  11.188525
# 29  91db  90_90   21004-1    1  0.000006  0.000007  1.229508  11.147541
# 30  91db  70_70   21004-2    1  0.000007  0.000008  1.270492  11.147541
# 31  91db  70_90   21004-2    1  0.000006  0.000010  1.229508  11.065574
# 32  91db  90_90   21004-2    1  0.000009  0.000010  1.188525  11.106557
# ...

# %%
print("\nno of columns:",animal_data.shape[1])
print("\nno of data points:",animal_data.shape[0])
# Out:
# no of columns: 104
#
# no of data points: 183

# %%
animal_data["Group"].value_counts()
# Out:
# Group
# control    90
# 96db       75
# 91db       18
# Name: count, dtype: int64

# %% [markdown]
# There are 3 diff kinds of groups:
# - control : animals that received no noise exposure
# - 96db : animals that were exposed to 96db for 2 hours
# - 91db : animals that were exposed to 91db for 2 hours

# %%
animal_data["Levels"].value_counts()
# Out:
# Levels
# 90_90    143
# 70_70     20
# 70_90     20
# Name: count, dtype: int64

# %% [markdown]
# There are 3 levels of ABR stimulus:
# could be loudness_frequency (yet to confirm)
# - 90_90 :
# - 70_70 :
# - 70_90 :

# %%
animal_data["SubjectID"].value_counts()
# Out:
# SubjectID
# 21000-1    3
# 21081-1    3
# 21081-3    3
# 21081-4    3
# 21082-1    3
#           ..
# 21077-3    3
# 21078-1    3
# 21078-2    3
# 21078-3    3
# 21092-2    3
# Name: count, Length: 61, dtype: int64

# %%
animal_data["Run"].value_counts()
# Out:
# Run
# 1    101
# 2     41
# 3     41
# Name: count, dtype: int64

# %%
## we can ignore this data column - this is based on how the data was collected (experiment conditions)
animal_data.drop(["Run"],axis=1,inplace=True)

# %%
ABR_before_noise = [col for col in animal_data.columns if 'T0' in col]
ABR_after_noise = [col for col in animal_data.columns if 'T2' in col]

# %% [markdown]
# - there are a total of 7 waves in the ABR readings
# - waves 1 to 5 are the most impt with wave 5 being the largest peak
# - abr readings taken during sleep/rest is recommended because the peaks are small so under normal circumstances can be susceptible to a lot of noise
# - how to plot the abr response for an animal ? plot the 5 wave values ?
# - wave 5 is used to detect whether the patient is hearing the noise or not

# %%
len(ABR_before_noise)
# Out:
# 50

# %%
len(ABR_after_noise)
# Out:
# 50

# %%
## visualize the before and after noise exposure for subject 21000-1
animal_data[animal_data['SubjectID']=='21000-1']
# Out:
#      Group Levels SubjectID  A_C1W1T0  A_C2W1T0  L_C1W1T0   L_C2W1T0  \
# 0  control  70_70   21000-1  0.000002  0.000003  1.352459  11.270492
# 1  control  70_90   21000-1  0.000002  0.000005  1.311475  11.188525
# 2  control  90_90   21000-1  0.000004  0.000004  1.311475  11.229508
#
#    A_C1W2T0  A_C2W2T0  L_C1W2T0  ...  rC_C2W2T2  lC_C2W3T2  cC_C2W3T2  \
# 0  0.000005  0.000006  2.090164  ...   0.000293   0.000197   0.000403
# 1  0.000005  0.000008  2.008197  ...   0.000430   0.000320   0.000375
# 2  0.000008  0.000008  2.049180  ...   0.000448   0.000302   0.000338
#
#    rC_C2W3T2  lC_C2W4T2  cC_C2W4T2  rC_C2W4T2  lC_C2W5T2  cC_C2W5T2  rC_C2W5T2
# 0   0.000258   0.000033   0.000092   0.000078   0.000058   0.000031   0.000016
# 1   0.000228   0.000090   0.000122   0.000080   0.000059   0.000041   0.000010
# 2   0.000209   0.000104   0.000096   0.000037   0.000078   0.000073   0.000030
#
# [3 rows x 103 columns]

# %%
## analyzing the A series wave pattern for one data point 
A_C1_T0 = np.array(animal_data[['A_C1W1T0','A_C1W2T0','A_C1W3T0','A_C1W4T0','A_C1W5T0']])
A_C2_T0 = np.array(animal_data[['A_C2W1T0','A_C2W2T0','A_C2W3T0','A_C2W4T0','A_C2W5T0']])
A_C1_T2 = np.array(animal_data[['A_C1W1T2','A_C1W2T2','A_C1W3T2','A_C1W4T2','A_C1W5T2']])
A_C2_T2 = np.array(animal_data[['A_C2W1T2','A_C2W2T2','A_C2W3T2','A_C2W4T2','A_C2W5T2']])
plt.plot(np.arange(1,6),A_C1_T0[0],label = 'C1')
plt.plot(np.arange(1,6),A_C2_T0[0],label='C2')
plt.plot(np.arange(1,6),A_C1_T2[0],label = 'C1 after')
plt.plot(np.arange(1,6),A_C2_T2[0],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.title('ABR waveform for metrics A_C1 and A_C2')
plt.legend()
plt.show()

# %%
## analyzing the A series wave pattern for one data point 
A_C2_T0 = np.array(animal_data[['A_C2W1T0','A_C2W2T0','A_C2W3T0','A_C2W4T0','A_C2W5T0']])
A_C2_T2 = np.array(animal_data[['A_C2W1T2','A_C2W2T2','A_C2W3T2','A_C2W4T2','A_C2W5T2']])
plt.plot(np.arange(1,6),A_C2_T0[0],label='C2')
plt.plot(np.arange(1,6),A_C2_T2[0],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.title('A_C2 for control')
plt.legend()
plt.show()

# %%
## analyzing the A series wave pattern for one data point 
A_C2_T0 = np.array(animal_data[['A_C2W1T0','A_C2W2T0','A_C2W3T0','A_C2W4T0','A_C2W5T0']])
A_C2_T2 = np.array(animal_data[['A_C2W1T2','A_C2W2T2','A_C2W3T2','A_C2W4T2','A_C2W5T2']])
plt.plot(np.arange(1,6),A_C2_T0[0],label='C2')
plt.plot(np.arange(1,6),A_C2_T2[0],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.title('A_C2 for control')
plt.legend()
plt.show()

# %%
## analyzing the A series wave pattern for one data point 
A_C2_T0 = np.array(animal_data[['A_C2W1T0','A_C2W2T0','A_C2W3T0','A_C2W4T0','A_C2W5T0']])
A_C2_T2 = np.array(animal_data[['A_C2W1T2','A_C2W2T2','A_C2W3T2','A_C2W4T2','A_C2W5T2']])
plt.plot(np.arange(1,6),A_C2_T0[180],label='C2')
plt.plot(np.arange(1,6),A_C2_T2[180],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.title('A_C2 for 96db')
plt.legend()
plt.show()

# %%
## analyzing the A series wave pattern for one data point 
A_C2_T0 = np.array(animal_data[['A_C2W1T0','A_C2W2T0','A_C2W3T0','A_C2W4T0','A_C2W5T0']])
A_C2_T2 = np.array(animal_data[['A_C2W1T2','A_C2W2T2','A_C2W3T2','A_C2W4T2','A_C2W5T2']])
plt.plot(np.arange(1,6),A_C2_T0[30],label='C2')
plt.plot(np.arange(1,6),A_C2_T2[30],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.title('A_C2 for 91db')
plt.legend()
plt.show()

# %%
## analyzing the A series wave pattern for one data point 
A_C1_T0 = np.array(animal_data[['A_C1W1T0','A_C1W2T0','A_C1W3T0','A_C1W4T0','A_C1W5T0']])
A_C2_T0 = np.array(animal_data[['A_C2W1T0','A_C2W2T0','A_C2W3T0','A_C2W4T0','A_C2W5T0']])
A_C1_T2 = np.array(animal_data[['A_C1W1T2','A_C1W2T2','A_C1W3T2','A_C1W4T2','A_C1W5T2']])
A_C2_T2 = np.array(animal_data[['A_C2W1T2','A_C2W2T2','A_C2W3T2','A_C2W4T2','A_C2W5T2']])
plt.plot(np.arange(1,6),A_C1_T0[42],label = 'C1')
plt.plot(np.arange(1,6),A_C2_T0[42],label='C2')
plt.plot(np.arange(1,6),A_C1_T2[42],label = 'C1 after')
plt.plot(np.arange(1,6),A_C2_T2[42],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.legend()
plt.show()

# %%
## analyzing the A series wave pattern for one data point 
L_C1_T0 = np.array(animal_data[['L_C1W1T0','L_C1W2T0','L_C1W3T0','L_C1W4T0','L_C1W5T0']])
L_C2_T0 = np.array(animal_data[['L_C2W1T0','L_C2W2T0','L_C2W3T0','L_C2W4T0','L_C2W5T0']])
L_C1_T2 = np.array(animal_data[['L_C1W1T2','L_C1W2T2','L_C1W3T2','L_C1W4T2','L_C1W5T2']])
L_C2_T2 = np.array(animal_data[['L_C2W1T2','L_C2W2T2','L_C2W3T2','L_C2W4T2','L_C2W5T2']])
plt.plot(np.arange(1,6),L_C1_T0[0],label = 'C1')
plt.plot(np.arange(1,6),L_C2_T0[0],label='C2')
plt.plot(np.arange(1,6),L_C1_T2[0],label = 'C1 after')
plt.plot(np.arange(1,6),L_C2_T2[0],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.title('ABR waveform for metrics L_C1 and L_C2')
plt.legend()
plt.show()

# %%
## analyzing the A series wave pattern for one data point 
L_C1_T0 = np.array(animal_data[['L_C1W1T0','L_C1W2T0','L_C1W3T0','L_C1W4T0','L_C1W5T0']])
L_C2_T0 = np.array(animal_data[['L_C2W1T0','L_C2W2T0','L_C2W3T0','L_C2W4T0','L_C2W5T0']])
L_C1_T2 = np.array(animal_data[['L_C1W1T2','L_C1W2T2','L_C1W3T2','L_C1W4T2','L_C1W5T2']])
L_C2_T2 = np.array(animal_data[['L_C2W1T2','L_C2W2T2','L_C2W3T2','L_C2W4T2','L_C2W5T2']])
plt.plot(np.arange(1,6),L_C1_T0[42],label = 'C1')
plt.plot(np.arange(1,6),L_C2_T0[42],label='C2')
plt.plot(np.arange(1,6),L_C1_T2[42],label = 'C1 after')
plt.plot(np.arange(1,6),L_C2_T2[42],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.legend()
plt.show()

# %%
cC_C1_T0 = np.array(animal_data[['cC_C1W1T0','cC_C1W2T0','cC_C1W3T0','cC_C1W4T0','cC_C1W5T0']])
cC_C2_T0 = np.array(animal_data[['cC_C2W1T0','cC_C2W2T0','cC_C2W3T0','cC_C2W4T0','cC_C2W5T0']])
cC_C1_T2 = np.array(animal_data[['cC_C1W1T2','cC_C1W2T2','cC_C1W3T2','cC_C1W4T2','cC_C1W5T2']])
cC_C2_T2 = np.array(animal_data[['cC_C2W1T2','cC_C2W2T2','cC_C2W3T2','cC_C2W4T2','cC_C2W5T2']])
plt.plot(np.arange(1,6),cC_C1_T0[0],label = 'C1')
plt.plot(np.arange(1,6),cC_C2_T0[0],label='C2')
plt.plot(np.arange(1,6),cC_C1_T2[0],label = 'C1 after')
plt.plot(np.arange(1,6),cC_C2_T2[0],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.title('ABR waveform for metrics cC_C1 and cC_C2')
plt.legend()
plt.show()

# %%
cC_C1_T0 = np.array(animal_data[['cC_C1W1T0','cC_C1W2T0','cC_C1W3T0','cC_C1W4T0','cC_C1W5T0']])
cC_C2_T0 = np.array(animal_data[['cC_C2W1T0','cC_C2W2T0','cC_C2W3T0','cC_C2W4T0','cC_C2W5T0']])
cC_C1_T2 = np.array(animal_data[['cC_C1W1T2','cC_C1W2T2','cC_C1W3T2','cC_C1W4T2','cC_C1W5T2']])
cC_C2_T2 = np.array(animal_data[['cC_C2W1T2','cC_C2W2T2','cC_C2W3T2','cC_C2W4T2','cC_C2W5T2']])
plt.plot(np.arange(1,6),cC_C1_T0[42],label = 'C1')
plt.plot(np.arange(1,6),cC_C2_T0[42],label='C2')
plt.plot(np.arange(1,6),cC_C1_T2[42],label = 'C1 after')
plt.plot(np.arange(1,6),cC_C2_T2[42],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.legend()
plt.show()

# %%
rC_C1_T0 = np.array(animal_data[['rC_C1W1T0','rC_C1W2T0','rC_C1W3T0','rC_C1W4T0','rC_C1W5T0']])
rC_C2_T0 = np.array(animal_data[['rC_C2W1T0','rC_C2W2T0','rC_C2W3T0','rC_C2W4T0','rC_C2W5T0']])
rC_C1_T2 = np.array(animal_data[['rC_C1W1T2','rC_C1W2T2','rC_C1W3T2','rC_C1W4T2','rC_C1W5T2']])
rC_C2_T2 = np.array(animal_data[['rC_C2W1T2','rC_C2W2T2','rC_C2W3T2','rC_C2W4T2','rC_C2W5T2']])
plt.plot(np.arange(1,6),rC_C1_T0[0],label = 'C1')
plt.plot(np.arange(1,6),rC_C2_T0[0],label='C2')
plt.plot(np.arange(1,6),rC_C1_T2[0],label = 'C1 after')
plt.plot(np.arange(1,6),rC_C2_T2[0],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.title('ABR waveform for metrics rC_C1 and rC_C2')
plt.legend()
plt.show()

# %%
lC_C1_T0 = np.array(animal_data[['lC_C1W1T0','lC_C1W2T0','lC_C1W3T0','lC_C1W4T0','lC_C1W5T0']])
lC_C2_T0 = np.array(animal_data[['lC_C2W1T0','lC_C2W2T0','lC_C2W3T0','lC_C2W4T0','lC_C2W5T0']])
lC_C1_T2 = np.array(animal_data[['lC_C1W1T2','lC_C1W2T2','lC_C1W3T2','lC_C1W4T2','lC_C1W5T2']])
lC_C2_T2 = np.array(animal_data[['lC_C2W1T2','lC_C2W2T2','lC_C2W3T2','lC_C2W4T2','lC_C2W5T2']])
plt.plot(np.arange(1,6),lC_C1_T0[0],label = 'C1')
plt.plot(np.arange(1,6),lC_C2_T0[0],label='C2')
plt.plot(np.arange(1,6),lC_C1_T2[0],label = 'C1 after')
plt.plot(np.arange(1,6),lC_C2_T2[0],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.title('ABR waveform for metrics lC_C1 and lC_C2')
plt.legend()
plt.show()

# %%
lC_C1_T0 = np.array(animal_data[['lC_C1W1T0','lC_C1W2T0','lC_C1W3T0','lC_C1W4T0','lC_C1W5T0']])
lC_C2_T0 = np.array(animal_data[['lC_C2W1T0','lC_C2W2T0','lC_C2W3T0','lC_C2W4T0','lC_C2W5T0']])
lC_C1_T2 = np.array(animal_data[['lC_C1W1T2','lC_C1W2T2','lC_C1W3T2','lC_C1W4T2','lC_C1W5T2']])
lC_C2_T2 = np.array(animal_data[['lC_C2W1T2','lC_C2W2T2','lC_C2W3T2','lC_C2W4T2','lC_C2W5T2']])
plt.plot(np.arange(1,6),lC_C1_T0[42],label = 'C1')
plt.plot(np.arange(1,6),lC_C2_T0[42],label='C2')
plt.plot(np.arange(1,6),lC_C1_T2[42],label = 'C1 after')
plt.plot(np.arange(1,6),lC_C2_T2[42],label='C2 after')
plt.xlabel('Wave number')
plt.ylabel('Reading value')
plt.legend()
plt.show()

# %%
total = animal_data.shape[0]
group_counts = animal_data['Group'].value_counts()
group_percentages = []

# %%
group_percentages = {group:group_counts[group]/total for group in animal_data['Group'].unique()}

# %%
group_percentages.values()
# Out:
# dict_values([0.4918032786885246, 0.09836065573770492, 0.4098360655737705])

# %%
plt.pie(group_percentages.values(), labels = group_percentages.keys(),autopct='%1.1f%%')
plt.show()

# %%
animal_data.head()
# Out:
#    Group SubjectID  Run  A_C1W1T0  A_C2W1T0  L_C1W1T0   L_C2W1T0  A_C1W2T0  \
# 0      0   21000-1    1  0.000002  0.000003  1.352459  11.270492  0.000005
# 1      0   21000-1    1  0.000002  0.000005  1.311475  11.188525  0.000005
# 2      0   21000-1    1  0.000004  0.000004  1.311475  11.229508  0.000008
# 3      0   21001-1    1  0.000006  0.000006  1.352459  11.270492  0.000005
# 4      0   21001-1    1  0.000005  0.000010  1.311475  11.188525  0.000006
#
#    A_C2W2T0  L_C1W2T0  ...  cC_C2W3T2  rC_C2W3T2  lC_C2W4T2  cC_C2W4T2  \
# 0  0.000006  2.090164  ...   0.000403   0.000258   0.000033   0.000092
# 1  0.000008  2.008197  ...   0.000375   0.000228   0.000090   0.000122
# 2  0.000008  2.049180  ...   0.000338   0.000209   0.000104   0.000096
# 3  0.000006  2.131148  ...   0.000188   0.000091   0.000044   0.000081
# 4  0.000008  2.049180  ...   0.000206   0.000140   0.000084   0.000098
#
#    rC_C2W4T2  lC_C2W5T2  cC_C2W5T2  rC_C2W5T2  Level_70_90  Level_90_90
# ...

# %%
animal_data.columns
# Out:
# Index(['Group', 'SubjectID', 'Run', 'A_C1W1T0', 'A_C2W1T0', 'L_C1W1T0',
#        'L_C2W1T0', 'A_C1W2T0', 'A_C2W2T0', 'L_C1W2T0',
#        ...
#        'rC_C2W3T2', 'lC_C2W4T2', 'cC_C2W4T2', 'rC_C2W4T2', 'lC_C2W5T2',
#        'cC_C2W5T2', 'rC_C2W5T2', 'Level_70_70', 'Level_70_90', 'Level_90_90'],
#       dtype='object', length=106)

# %%
## ONE HOT ENCODE THE LEVELS 
animal_data = pd.get_dummies(animal_data, columns=['Levels'], prefix='Level', drop_first=False)

# %%
## LABEL ENCODE THE GROUPS
animal_data['Group'].replace('control',0,inplace=True)
animal_data['Group'].replace('91db',1,inplace=True)
animal_data['Group'].replace('96db',2,inplace=True)

# %%
## DEFINE THE MODELS
## HYPERPARAMETER OPTIMIZATION TO FIND THE BEST MODEL
## SAME MODEL - CHECK VARIABLE IMPORTANCE - CALC WITH AND WITHOUT THAT FEATURE

# %%
features_to_train = animal_data.columns[4:]
features_to_train
# Out:
# Index(['A_C1W1T0', 'A_C2W1T0', 'L_C1W1T0', 'L_C2W1T0', 'A_C1W2T0', 'A_C2W2T0',
#        'L_C1W2T0', 'L_C2W2T0', 'A_C1W3T0', 'A_C2W3T0', 'L_C1W3T0', 'L_C2W3T0',
#        'A_C1W4T0', 'A_C2W4T0', 'L_C1W4T0', 'L_C2W4T0', 'A_C1W5T0', 'A_C2W5T0',
#        'L_C1W5T0', 'L_C2W5T0', 'lC_C1W1T0', 'cC_C1W1T0', 'rC_C1W1T0',
#        'lC_C1W2T0', 'cC_C1W2T0', 'rC_C1W2T0', 'lC_C1W3T0', 'cC_C1W3T0',
#        'rC_C1W3T0', 'lC_C1W4T0', 'cC_C1W4T0', 'rC_C1W4T0', 'lC_C1W5T0',
#        'cC_C1W5T0', 'rC_C1W5T0', 'lC_C2W1T0', 'cC_C2W1T0', 'rC_C2W1T0',
#        'lC_C2W2T0', 'cC_C2W2T0', 'rC_C2W2T0', 'lC_C2W3T0', 'cC_C2W3T0',
#        'rC_C2W3T0', 'lC_C2W4T0', 'cC_C2W4T0', 'rC_C2W4T0', 'lC_C2W5T0',
#        'cC_C2W5T0', 'rC_C2W5T0', 'A_C1W1T2', 'A_C2W1T2', 'L_C1W1T2',
#        'L_C2W1T2', 'A_C1W2T2', 'A_C2W2T2', 'L_C1W2T2', 'L_C2W2T2', 'A_C1W3T2',
#        'A_C2W3T2', 'L_C1W3T2', 'L_C2W3T2', 'A_C1W4T2', 'A_C2W4T2', 'L_C1W4T2',
#        'L_C2W4T2', 'A_C1W5T2', 'A_C2W5T2', 'L_C1W5T2', 'L_C2W5T2', 'lC_C1W1T2',
# ...

# %%
for col in animal_data.columns:
    print(col,':',animal_data[col].isnull().sum())
    if animal_data[col].isnull().sum() !=0:
        animal_data[col].fillna(animal_data[col].mean(), inplace=True)
# Out:
# Group : 0
# SubjectID : 0
# A_C1W1T0 : 0
# A_C2W1T0 : 0
# L_C1W1T0 : 0
# L_C2W1T0 : 0
# A_C1W2T0 : 4
# A_C2W2T0 : 0
# L_C1W2T0 : 0
# L_C2W2T0 : 0
# A_C1W3T0 : 0
# A_C2W3T0 : 3
# L_C1W3T0 : 0
# L_C2W3T0 : 0
# A_C1W4T0 : 0
# A_C2W4T0 : 15
# L_C1W4T0 : 0
# L_C2W4T0 : 0
# A_C1W5T0 : 8
# A_C2W5T0 : 21
# L_C1W5T0 : 3
# L_C2W5T0 : 12
# lC_C1W1T0 : 0
# cC_C1W1T0 : 0
# rC_C1W1T0 : 0
# lC_C1W2T0 : 0
# cC_C1W2T0 : 0
# rC_C1W2T0 : 0
# lC_C1W3T0 : 0
# cC_C1W3T0 : 0
# rC_C1W3T0 : 0
# lC_C1W4T0 : 0
# cC_C1W4T0 : 0
# rC_C1W4T0 : 0
# lC_C1W5T0 : 3
# cC_C1W5T0 : 3
# rC_C1W5T0 : 3
# lC_C2W1T0 : 0
# cC_C2W1T0 : 0
# rC_C2W1T0 : 0
# lC_C2W2T0 : 0
# cC_C2W2T0 : 0
# rC_C2W2T0 : 0
# lC_C2W3T0 : 0
# cC_C2W3T0 : 0
# rC_C2W3T0 : 0
# lC_C2W4T0 : 0
# cC_C2W4T0 : 0
# rC_C2W4T0 : 0
# lC_C2W5T0 : 13
# cC_C2W5T0 : 13
# rC_C2W5T0 : 13
# A_C1W1T2 : 3
# A_C2W1T2 : 1
# L_C1W1T2 : 0
# L_C2W1T2 : 0
# A_C1W2T2 : 9
# A_C2W2T2 : 0
# L_C1W2T2 : 0
# L_C2W2T2 : 0
# A_C1W3T2 : 3
# A_C2W3T2 : 2
# L_C1W3T2 : 0
# L_C2W3T2 : 0
# ...

# %%
animal_data.isnull().sum()
# Out:
# Group          0
# SubjectID      0
# A_C1W1T0       0
# A_C2W1T0       0
# L_C1W1T0       0
#               ..
# cC_C2W5T2      0
# rC_C2W5T2      0
# Level_70_70    0
# Level_70_90    0
# Level_90_90    0
# Length: 105, dtype: int64

# %%
X_train
# Out:
#     SubjectID  Run  A_C1W1T0  A_C2W1T0  L_C1W1T0   L_C2W1T0  A_C1W2T0  \
# 65    21077-2    3  0.000005  0.000004  1.393443  11.352459  0.000007
# 67    21075-2    2  0.000009  0.000008  1.352459  11.270492  0.000004
# 31    21004-2    1  0.000006  0.000010  1.229508  11.065574  0.000009
# 12    21001-4    1  0.000006  0.000006  1.311475  11.229508  0.000009
# 41    20408-2    1  0.000011  0.000011  1.270492  11.188525  0.000007
# ..        ...  ...       ...       ...       ...        ...       ...
# 106   21082-1    2  0.000008  0.000008  1.311475  11.188525  0.000006
# 14    21001-4    1  0.000007  0.000006  1.229508  11.147541  0.000013
# 92    21080-4    3  0.000009  0.000009  1.352459  11.270492  0.000007
# 179   21089-3    3  0.000005  0.000004  1.311475  11.147541  0.000006
# 102   21081-4    1  0.000005  0.000005  1.311475  11.229508  0.000005
#
#      A_C2W2T0  L_C1W2T0   L_C2W2T0  ...  rC_C2W2T2  lC_C2W3T2  cC_C2W3T2  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
Y = animal_data['Group']
X = animal_data[features_to_train]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
y_train.value_counts()
# Out:
# Group
# 0    72
# 2    60
# 1    14
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# Group
# 0    18
# 2    15
# 1     4
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the StandardScaler
zscore_scaler = MinMaxScaler()

numeric_columns = X_train.select_dtypes(include=['float64', 'int64']).columns

X_train_normalized = X_train.copy()  
X_train_normalized[numeric_columns] = zscore_scaler.fit_transform(X_train[numeric_columns])

# Transform the testing data using the same scaler to avoid data leakage
X_test_normalized = X_test.copy()  
X_test_normalized[numeric_columns] = zscore_scaler.transform(X_test[numeric_columns])

# %% [markdown]
# ### Data Distribution

# %%
control_df = animal_data[animal_data['Group'] == 'control']
db96_df = animal_data[animal_data['Group'] == '96db']
db91_df = animal_data[animal_data['Group'] == '91db']

# %%
import matplotlib.pyplot as plt

# Select the columns you want to include in the boxplot
columns_to_plot = ['A_C1W1T0', 'A_C2W1T0', 'L_C1W1T0', 'L_C2W1T0', 'A_C1W2T0', 'A_C2W2T0', 'L_C1W2T0', 'L_C2W2T0']

# Use the selected columns along with the 'Group' column to create the boxplot
animal_data.boxplot(column=columns_to_plot, by='Group', layout=(2, 4), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of Selected Columns by Group')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# initialize the MinMaxScaler
zscore_scaler = MinMaxScaler()

numeric_columns = animal_data.select_dtypes(include=['float64', 'int64']).columns

animal_data_normalized = animal_data.copy()  
animal_data_normalized[numeric_columns] = zscore_scaler.fit_transform(animal_data[numeric_columns])

# %%
# columns to include in the boxplot
columns_to_plot = ['A_C1W1T0', 'A_C2W1T0', 'A_C1W2T0', 'A_C2W2T0','A_C1W3T0', 'A_C2W3T0','A_C1W4T0', 'A_C2W4T0','A_C1W5T0', 'A_C2W5T0']

# Use the selected columns along with the 'Group' column to create the boxplot
animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric A by Group')
plt.show()

# %%
columns_to_plot = ['A_C1W1T2', 'A_C2W1T2', 'A_C1W2T2', 'A_C2W2T2','A_C1W3T2', 'A_C2W3T2',
                   'A_C1W4T2', 'A_C2W4T2','A_C1W5T2', 'A_C2W5T2']

animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric A, after noise exposure')
plt.show()

# %%
columns_to_plot = ['L_C1W1T0', 'L_C2W1T0', 'L_C1W2T0', 'L_C2W2T0','L_C1W3T0', 
                   'L_C2W3T0','L_C1W4T0', 'L_C2W4T0','L_C1W5T0', 'L_C2W5T0']

animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric L by Group')
plt.show()

# %%
columns_to_plot = ['L_C1W1T2', 'L_C2W1T2', 'L_C1W2T2', 'L_C2W2T2','L_C1W3T2', 
                   'L_C2W3T2','L_C1W4T2', 'L_C2W4T2','L_C1W5T2', 'L_C2W5T2']

animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric, after noise exposure')
plt.show()

# %%
columns_to_plot = ['cC_C1W1T0', 'cC_C2W1T0', 'cC_C1W2T0', 'cC_C2W2T0','cC_C1W3T0', 
                   'cC_C2W3T0','cC_C1W4T0', 'cC_C2W4T0','cC_C1W5T0', 'cC_C2W5T0']

animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric cC by Group')
plt.show()

# %%
columns_to_plot = ['cC_C1W1T2', 'cC_C2W1T2', 'cC_C1W2T2', 'cC_C2W2T2','cC_C1W3T2', 
                   'cC_C2W3T2','cC_C1W4T2', 'cC_C2W4T2','cC_C1W5T2', 'cC_C2W5T2']

animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric cC, after noise exposure')
plt.show()

# %%
columns_to_plot = ['rC_C1W1T0', 'rC_C2W1T0', 'rC_C1W2T0', 'rC_C2W2T0','rC_C1W3T0', 
                   'rC_C2W3T0','rC_C1W4T0', 'rC_C2W4T0','rC_C1W5T0', 'rC_C2W5T0']

animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric rC by Group')
plt.show()

# %%
columns_to_plot = ['rC_C1W1T2', 'rC_C2W1T2', 'rC_C1W2T2', 'rC_C2W2T2','rC_C1W3T2', 
                   'rC_C2W3T2','rC_C1W4T2', 'rC_C2W4T2','rC_C1W5T2', 'rC_C2W5T2']

animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric rC, after noise exposure')
plt.show()

# %%
columns_to_plot = ['lC_C1W1T0', 'lC_C2W1T0', 'lC_C1W2T0', 'lC_C2W2T0','lC_C1W3T0', 
                   'lC_C2W3T0','lC_C1W4T0', 'lC_C2W4T0','lC_C1W5T0', 'lC_C2W5T0']

animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric lC by Group')
plt.show()

# %%
columns_to_plot = ['lC_C1W1T2', 'lC_C2W1T2', 'lC_C1W2T2', 'lC_C2W2T2','lC_C1W3T2', 
                   'lC_C2W3T2','lC_C1W4T2', 'lC_C2W4T2','lC_C1W5T2', 'lC_C2W5T2']

animal_data_normalized.boxplot(column=columns_to_plot, by='Group', layout=(2, 5), figsize=(15, 8), grid=False)
plt.suptitle('Boxplot of ABR metric lC, after noise exposure')
plt.show()

# %%
## INTERPRETABILITY ACROSS MODELS VISUALIZATION 
## values obtained from other notebooks
lr_features = ['cC_C2W1T2', 'A_C2W1T2', 'cC_C1W1T2', 'lC_C1W1T2', 'rC_C2W5T2',
       'rC_C1W1T2', 'A_C1W1T2', 'lC_C2W1T2', 'cC_C1W4T2', 'lC_C2W5T2',
       'rC_C2W1T2', 'lC_C2W2T2']
dt_features = ['A_C2W1T2', 'lC_C1W5T0', 'A_C2W2T0', 'A_C2W3T0', 'cC_C2W3T2']
ada_features = ['A_C1W1T2', 'rC_C1W1T2', 'A_C2W1T2', 'cC_C2W1T2', 'lC_C1W3T0',
       'cC_C1W4T2', 'cC_C1W5T0', 'A_C1W3T0', 'L_C1W5T2', 'cC_C2W3T2',
       'cC_C2W2T0', 'cC_C2W1T0', 'cC_C2W2T2', 'rC_C1W4T0', 'A_C2W4T2',
       'lC_C1W2T2', 'cC_C1W1T2', 'rC_C2W1T2', 'lC_C2W1T2', 'cC_C1W3T2',
       'L_C2W5T2', 'L_C1W4T2', 'rC_C2W5T2', 'rC_C2W3T2']
ebm_features = ['A_C1W5T0', 'lC_C1W2T2', 'lC_C1W4T0', 'cC_C2W1T0', 'rC_C2W2T2',
       'cC_C2W2T2', 'lC_C2W4T2', 'cC_C2W4T0', 'lC_C1W5T0', 'rC_C2W1T0',
       'A_C1W5T2', 'cC_C1W3T2', 'A_C1W2T2', 'L_C2W2T2', 'Level_90_90',
       'L_C1W5T2', 'cC_C2W4T2', 'rC_C1W2T0', 'rC_C2W3T2', 'A_C2W5T2',
       'L_C1W2T2', 'rC_C1W2T2', 'A_C2W2T0', 'rC_C1W4T0', 'rC_C1W1T0',
       'rC_C2W2T0', 'A_C1W3T2', 'cC_C1W3T0', 'cC_C2W3T0', 'A_C1W1T2',
       'L_C1W5T0', 'lC_C2W2T2', 'L_C2W4T0', 'L_C2W4T2', 'lC_C1W4T2',
       'cC_C2W1T2', 'L_C2W2T0', 'rC_C1W1T2', 'A_C2W1T2', 'lC_C1W3T2',
       'A_C2W3T2', 'cC_C1W2T0', 'rC_C1W4T2', 'lC_C2W5T2', 'A_C2W5T0',
       'A_C2W4T0', 'A_C2W3T0', 'lC_C1W3T0', 'L_C2W5T2', 'L_C2W1T2',
       'Level_70_70', 'rC_C1W5T0', 'cC_C1W4T2', 'L_C1W4T2', 'L_C2W3T2',
       'rC_C2W4T0', 'cC_C1W5T0', 'rC_C1W3T2', 'A_C2W2T2', 'A_C2W4T2',
       'L_C1W3T2', 'cC_C1W5T2', 'cC_C1W1T0', 'rC_C2W3T0', 'lC_C2W3T0',
       'cC_C1W1T2', 'A_C1W2T0']

# %%
common_features = set(lr_features) & set(dt_features) & set(ada_features) & set(ebm_features)
common_features
# Out:
# {'A_C2W1T2'}

# %%
lr_ebm= set(lr_features) & set(ebm_features)
lr_ebm
# Out:
# {'A_C1W1T2',
#  'A_C2W1T2',
#  'cC_C1W1T2',
#  'cC_C1W4T2',
#  'cC_C2W1T2',
#  'lC_C2W2T2',
#  'lC_C2W5T2',
#  'rC_C1W1T2'}

# %%
lr_ada= set(lr_features) & set(ada_features)
lr_ada
# Out:
# {'A_C1W1T2',
#  'A_C2W1T2',
#  'cC_C1W1T2',
#  'cC_C1W4T2',
#  'cC_C2W1T2',
#  'lC_C2W1T2',
#  'rC_C1W1T2',
#  'rC_C2W1T2',
#  'rC_C2W5T2'}

# %%
dt_ada = set(dt_features) & set(ada_features)
dt_ada
# Out:
# {'A_C2W1T2', 'cC_C2W3T2'}

# %%
dt_ada = set(dt_features) & set(ebm_features)
dt_ada
# Out:
# {'A_C2W1T2', 'A_C2W2T0', 'A_C2W3T0', 'lC_C1W5T0'}

# %%
set(ada_features) & set(ebm_features)
# Out:
# {'A_C1W1T2',
#  'A_C2W1T2',
#  'A_C2W4T2',
#  'L_C1W4T2',
#  'L_C1W5T2',
#  'L_C2W5T2',
#  'cC_C1W1T2',
#  'cC_C1W3T2',
#  'cC_C1W4T2',
#  'cC_C1W5T0',
#  'cC_C2W1T0',
#  'cC_C2W1T2',
#  'cC_C2W2T2',
#  'lC_C1W2T2',
#  'lC_C1W3T0',
#  'rC_C1W1T2',
#  'rC_C1W4T0',
#  'rC_C2W3T2'}
